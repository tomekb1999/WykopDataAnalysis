# %% [markdown]
# The purpose of this notebook is to load users' posts from <b>wykop.pl</b> and save them in a CSV file for further analysis. To achieve this, we will utilize the <b>Wykop API</b>. First, let's load the necessary modules:

# %%
import requests
import pandas as pd
import seaborn as sns

# %% [markdown]
# Now we will create a few helpful variables to establish some parameters.

# %%
public_key = "your_public_API_key"
private_key = "your_private_API_key"
tag = "gownowpis" # hashtag name we will download entries from
n_of_entries = 2000 # number of entries to load,must be multiple of 50
year = 2024
month = 2
save_folder_path = "data" # path to folder where you want to save CSV file with loaded entries

# %% [markdown]
# In order to use the <b>Wykop API</b>, we first have to generate a token using our public and private keys. This token will be necessary for other API methods. Token generation is easy and is done by sending a proper POST request to the <code>/auth</code> address.

# %%
data = {"data": {
    "key": public_key,
    "secret": private_key
  },
}
print("Authorization...")
auth_req = requests.post("https://wykop.pl/api/v3/auth", json=data)
token = auth_req.json()['data']['token']
print("Token:", token)

# %% [markdown]
# Now, in order to download entries from a specific hashtag, we need to send a GET request to <code>/tags/{tagName}/stream</code>, where <code>{tagName}</code> is the desired hashtag name. It is convenient to load the data into a pandas DataFrame. The maximum number of entries we can download at once is 50, so to load more than that, we perform multiple requests and then join them together.

# %%
headers = {
    'Authorization': f'Bearer {token}'
}
pages_tab = []
for i in range(int(n_of_entries/50)):
    params = {
        'page': i,
        'limit': 50, # max 50
        'sort': 'all',
        'type': 'entry',
        'year': year,
        'month': month
    }
    print("Downloading page", i+1)
    response = requests.get(f'https://wykop.pl/api/v3/tags/{tag}/stream', params=params, headers=headers)
    pages_tab.append(pd.DataFrame(response.json()['data']))
data = pd.concat(pages_tab)
print("Data loaded. Shape:", data.shape)
data.head()
# Out:
# Downloading page 1
# Downloading page 2
# Downloading page 3
# Downloading page 4
# Downloading page 5
# Downloading page 6
# Downloading page 7
# Downloading page 8
# Downloading page 9
# Downloading page 10
# Downloading page 11
# Downloading page 12
# Downloading page 13
# Downloading page 14
# Downloading page 15
# Downloading page 16
# Downloading page 17
# Downloading page 18
# Downloading page 19
# Downloading page 20
# Downloading page 21
# Downloading page 22
# Downloading page 23
# Downloading page 24
# Downloading page 25
# Downloading page 26
# Downloading page 27
# Downloading page 28
# Downloading page 29
# Downloading page 30
# Downloading page 31
# Downloading page 32
# Downloading page 33
# Downloading page 34
# Downloading page 35
# Downloading page 36
# Downloading page 37
# Downloading page 38
# Downloading page 39
# Downloading page 40
# Data loaded. Shape: (1290, 20)
#          id                                               slug  \
# 0  75246945  mam-wrazenie-ze-w-telewizji-leca-tylko-3-rekla...
# 1  75246657                 lizme-stupki-natychmiast-gownowpis
# 2  75246421  umyje-sie-dzis-od-stop-po-czubek-glowy-szarym-...
# 3  75246367                  heheszki-humorobrazkowy-gownowpis
# 4  75246323                     przegryw-kiciochpyta-gownowpis
#
#                                               author device  \
# 0  {'username': 'Kopyto96', 'gender': None, 'comp...
# 1  {'username': 'vikop-ru', 'gender': 'f', 'compa...
# 2  {'username': 'ItsyBitsyPajonk', 'gender': 'm',...
# 3  {'username': 'pogop', 'gender': 'm', 'company'...
# 4  {'username': 'niedorzecznybubr', 'gender': 'm'...
#
#             created_at  voted  \
# 0  2024-02-29 22:52:00      0
# 1  2024-02-29 22:25:00      0
# 2  2024-02-29 22:08:17      0
# 3  2024-02-29 22:04:33      0
# 4  2024-02-29 22:02:05      0
#
#                                              content  \
# 0  Mam wrażenie, że w telewizji lecą tylko 3 rekl...
# 1             Liżme stupki natychmiast\n\n#gownowpis
# 2  Umyję się dziś od stóp po czubek głowy szarym ...
# 3               #heheszki #humorobrazkowy #gownowpis
# 4                  #przegryw #kiciochpyta #gownowpis
#
#                                                media  adult  \
# 0     {'photo': None, 'embed': None, 'survey': None}  False
# 1     {'photo': None, 'embed': None, 'survey': None}  False
# 2     {'photo': None, 'embed': None, 'survey': None}  False
# 3  {'photo': {'key': 'xRQ1D37lOaMPgwX49B5n0jMy9V2...  False
# 4  {'photo': None, 'embed': None, 'survey': {'key...  False
#
#                                                 tags  favourite parent  \
# 0  [reklama, telewizja, zalesie, gownowpis, niebi...      False   None
# 1                                        [gownowpis]      False   None
# 2                         [gownowpis, zzyciapajonka]      False   None
# 3              [heheszki, humorobrazkowy, gownowpis]      False   None
# 4                 [przegryw, kiciochpyta, gownowpis]      False   None
#
#                                                votes  editable  deletable  \
# 0  {'up': 2, 'down': 0, 'users': [{'username': 'W...     False      False
# 1                  {'up': 0, 'down': 0, 'users': []}     False      False
# 2  {'up': 2, 'down': 0, 'users': [{'username': 'p...     False      False
# 3  {'up': 105, 'down': 0, 'users': [{'username': ...     False      False
# 4                  {'up': 0, 'down': 0, 'users': []}     False      False
#
#                                             comments resource  \
# 0  {'items': [{'id': 264795361, 'slug': 'kopyto96...    entry
# 1  {'items': [{'id': 264794819, 'slug': 'vikop-ru...    entry
# 2  {'items': [{'id': 264793397, 'slug': 'umyje-si...    entry
# 3                          {'items': [], 'count': 0}    entry
# 4  {'items': [{'id': 264793163, 'slug': 'niedorze...    entry
#
#                                              actions  archive   status
# 0  {'create': False, 'update': False, 'delete': F...    False  visible
# 1  {'create': False, 'update': False, 'delete': F...    False  visible
# 2  {'create': False, 'update': False, 'delete': F...    False  visible
# 3  {'create': False, 'update': False, 'delete': F...    False  visible
# 4  {'create': False, 'update': False, 'delete': F...    False  visible

# %% [markdown]
# At the end, let's save the downloaded data into a CSV file for further analysis.

# %%
data.to_csv(f"{save_folder_path}/{tag}.csv")
